# %%
#Import Local files
import sys
sys.path.append("..") 
from FractalCreation import FractalCreation
import csv
import numpy

# %%
#Specify the settings used here 

rmin = -3
rmax = 1
imin = -2
imax = 2

bits = 5000

FilePath = "Data/test_data2.csv"

# %%
matrix2 = np.genfromtxt(FilePath, delimiter=",")

# %%
quality = matrix2.shape[0]
dpi_val = quality/20 
matrix2.shape, quality, dpi_val
# Out:
# ((5000, 5001), 5000, 250.0)

# %%
#Make Fractal Creation Object
OBJ = FractalCreation(rmin, rmax, imin, imax, quality)

# %%
#Data Cleaning 
atrix2 = np.delete(matrix2, -1, 1) 
matrix2[matrix2 == 0] = np.nan

# %%
matrix2.shape

# %%
# Out:
# (5000, 5000)

# %%
#Plot and save the image 
OBJ.PlotSave(Matrix=matrix2, name=f'LWF3_Quality_{quality}_Bits_{bits}', DPI=dpi_val, loadColor=True)
# Out:
# Time: 0.0 s
